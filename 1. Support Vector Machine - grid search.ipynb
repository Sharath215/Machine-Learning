# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1333           0
# 1334           0
# 1335           0
# 1336           0
# 1337           1
#
# [1338 rows x 8 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male',
#        'smoker_no', 'smoker_yes'],
#       dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_female', 'sex_male','smoker_no', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes
# 0      19  27.900         0           1         0          0           1
# 1      18  33.770         1           0         1          1           0
# 2      28  33.000         3           0         1          1           0
# 3      33  22.705         0           0         1          1           0
# 4      32  28.880         0           0         1          1           0
# ...   ...     ...       ...         ...       ...        ...         ...
# 1333   50  30.970         3           0         1          1           0
# 1334   18  31.920         0           1         0          1           0
# 1335   18  36.850         0           1         0          1           0
# 1336   21  25.800         0           1         0          1           0
# 1337   61  29.070         0           1         0          0           1
#
# [1338 rows x 7 columns]

# %%
dependent = dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(independent,dependent,test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR  # importing Support vector machine model.

param_grid = {'kernel':['rbf','poly','sigmoid','linear'],'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}

grid = GridSearchCV(SVR(),param_grid, refit = True, verbose = 3, n_jobs=-1)


grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\91967\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
# grid_predictions = grid.predict(X_test)
# from sklearn.metrics import r2_score
# r_score = r2_score(y_test, grid_predictions)

re = grid.cv_results_

print("the R score value for best parameter {}:".format(grid.best_params_))
# Out:
# the R score value for best parameter {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}:

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.081638      0.003196         0.036826        0.003924      10
# 1        0.076042      0.006182         0.014408        0.003197      10
# 2        0.086443      0.005972         0.014406        0.003202      10
# 3        0.064015      0.000012         0.011210        0.003932      10
# 4        0.072009      0.005058         0.038435        0.003195      10
# 5        0.064023      0.005065         0.012803        0.003915      10
# 6        0.076816      0.006404         0.014411        0.003206      10
# 7        0.062405      0.005976         0.011202        0.003922      10
# 8        0.071224      0.005304         0.037617        0.003201     100
# 9        0.070423      0.005987         0.009602        0.003198     100
# 10       0.073622      0.003200         0.016001        0.000002     100
# 11       0.077433      0.009125         0.010507        0.004925     100
# 12       0.075430      0.004159         0.039722        0.000229     100
# 13       0.069038      0.003901         0.019109        0.006209     100
# 14       0.081739      0.003409         0.016010        0.000018     100
# 15       0.075240      0.006391         0.009599        0.003202     100
# 16       0.097700      0.011763         0.038465        0.003240    1000
# 17       0.088931      0.008174         0.014603        0.001828    1000
# 18       0.084706      0.003679         0.015558        0.003438    1000
# 19       0.094568      0.006019         0.011200        0.003918    1000
# 20       0.088919      0.001554         0.033615        0.003218    1000
# 21       0.085614      0.004809         0.013616        0.003199    1000
# 22       0.084825      0.003929         0.016005        0.000007    1000
# 23       0.084019      0.003590         0.012010        0.003584    1000
# 24       0.088077      0.000090         0.040050        0.004985    2000
# 25       0.163392      0.036717         0.012808        0.003925    2000
# 26       0.088168      0.007162         0.014414        0.003199    2000
# 27       0.109639      0.013766         0.010408        0.004799    2000
# 28       0.092834      0.003928         0.035204        0.003916    2000
# 29       0.142439      0.035211         0.010408        0.003204    2000
# 30       0.086430      0.010609         0.014401        0.003200    2000
# 31       0.112035      0.013384         0.014404        0.003203    2000
# 32       0.100039      0.006210         0.038411        0.003198    3000
# 33       0.115236      0.003918         0.011210        0.003921    3000
# 34       0.089631      0.005991         0.016008        0.000006    3000
# 35       0.119238      0.009605         0.013604        0.003197    3000
# 36       0.094427      0.003200         0.036812        0.003929    3000
# 37       0.129748      0.017226         0.011580        0.003677    3000
# 38       0.081913      0.009177         0.012826        0.003938    3000
# 39       0.083214      0.015224         0.006452        0.003227    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.005885
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.143012
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.071989
# 3      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.520428
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.006201
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.137849
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.070972
# 7     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.520428
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.386830
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.663124
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.514733
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.601691
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.388846
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.656196
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.514878
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.601691
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.752049
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.804126
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.287063
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.669960
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.752675
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.804313
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.299261
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.669960
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.801270
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.804726
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.369915
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.669818
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.801468
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.804736
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.301714
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.669818
# 32      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.802499
# 33     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.803093
# 34  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -4.830472
# 35   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.669814
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.802822
# 37    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.803372
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -5.600202
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.669814
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.031286          -0.106263          -0.069245
# 1            0.152545           0.043211           0.091948
# 2            0.097945          -0.037522           0.002100
# 3            0.574646           0.471575           0.503311
# 4            0.031264          -0.106469          -0.069270
# 5            0.153024           0.047698           0.092572
# 6            0.098015          -0.037040           0.002181
# 7            0.574646           0.471575           0.503311
# 8            0.385873           0.244362           0.296466
# 9            0.681280           0.661067           0.694513
# 10           0.559262           0.465913           0.491065
# 11           0.643605           0.578829           0.596240
# 12           0.385726           0.242971           0.296277
# 13           0.681812           0.665700           0.695106
# 14           0.559069           0.466964           0.490980
# 15           0.643605           0.578829           0.596240
# 16           0.729686           0.715014           0.741375
# 17           0.789909           0.849634           0.808857
# 18           0.315633           0.213762           0.242796
# 19           0.591501           0.586922           0.572859
# 20           0.729633           0.714695           0.741322
# 21           0.789883           0.849579           0.808868
# 22           0.250498           0.205285           0.241985
# 23           0.591501           0.586922           0.572859
# 24           0.769885           0.834218           0.803325
# 25           0.785658           0.855024           0.804653
# 26          -1.921987          -0.865313          -2.032863
# 27           0.588888           0.587151           0.572786
# 28           0.769872           0.833848           0.803300
# 29           0.785639           0.855149           0.804626
# 30          -1.931124          -1.887239          -0.517725
# 31           0.588888           0.587151           0.572786
# 32           0.777930           0.851381           0.813981
# 33           0.784416           0.854772           0.804464
# 34          -4.987138          -3.013626          -5.152202
# 35           0.588850           0.587087           0.569527
# 36           0.777909           0.851351           0.813960
# 37           0.784361           0.854766           0.804409
# 38          -4.973272          -3.096306          -4.207897
# 39           0.588850           0.587087           0.569527
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.092375        -0.046143        0.054750               35
# 1            0.040453         0.094234        0.047498               32
# 2           -0.026300         0.021642        0.053921               33
# 3            0.449748         0.503942        0.043025               23
# 4           -0.092473        -0.046150        0.054868               36
# 5            0.042541         0.094737        0.045162               31
# 6           -0.026006         0.021625        0.053589               34
# 7            0.449748         0.503942        0.043025               23
# 8            0.240960         0.310898        0.064674               27
# 9            0.576512         0.655299        0.041267               14
# 10           0.449675         0.496130        0.038545               26
# 11           0.548474         0.593768        0.031072               21
# 12           0.240276         0.310819        0.065560               28
# 13           0.578376         0.655438        0.040776               13
# 14           0.449904         0.496359        0.038279               25
# 15           0.548474         0.593768        0.031072               21
# 16           0.635281         0.714681        0.041566               11
# 17           0.747304         0.799966        0.032978                6
# 18           0.343342         0.280519        0.047121               29
# 19           0.556116         0.595471        0.039237               15
# 20           0.634934         0.714652        0.041801               12
# 21           0.747574         0.800043        0.032882                5
# 22           0.340438         0.267493        0.047201               30
# 23           0.556116         0.595471        0.039237               15
# 24           0.721356         0.786011        0.038201                9
# 25           0.753065         0.800625        0.033101                2
# 26          -0.339298        -1.105875        0.736545               38
# 27           0.557014         0.595132        0.039072               17
# 28           0.721191         0.785936        0.038179               10
# 29           0.753123         0.800654        0.033127                1
# 30          -0.297541        -0.987069        0.757230               37
# 31           0.557014         0.595132        0.039072               17
# 32           0.735360         0.796230        0.038564                8
# 33           0.754037         0.800157        0.032817                4
# 34          -3.589338        -4.314555        0.853059               40
# 35           0.557016         0.594459        0.039466               19
# 36           0.735248         0.796258        0.038602                7
# 37           0.753957         0.800173        0.032847                3
# 38          -3.322618        -4.240059        0.952732               39
# 39           0.557016         0.594459        0.039466               19

# %%
age_input = float(input("Age:"))
bmi_input = float(input("BMI:"))
children_input = float(input("Children:"))
sex_male_input = int(input("sex male 0 or 1:"))
smoker_yes_input = int(input("smoker yes 0 or 1:"))
# Out:
# Age:32
# BMI:43
# Children:2
# sex male 0 or 1:0
# smoker yes 0 or 1:1

# %%
Future_Prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 Future_Prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#       2 print("Future_Prediction={}".format(Future_Prediction))
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:519, in BaseSearchCV.predict(self, X)
#     501 """Call predict on the estimator with the best found parameters.
#     502
#     503 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     516     the best found parameters.
#     517 """
#     518 check_is_fitted(self)
# --> 519 return self.best_estimator_.predict(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:431, in BaseLibSVM.predict(self, X)
#     415 def predict(self, X):
#     416     """Perform regression on samples in X.
#     417
#     418     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     429         The predicted values.
#     430     """
# --> 431     X = self._validate_for_predict(X)
#     432     predict = self._sparse_predict if self._sparse else self._dense_predict
#     433     return predict(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:611, in BaseLibSVM._validate_for_predict(self, X)
#     608 check_is_fitted(self)
#     610 if not callable(self.kernel):
# --> 611     X = self._validate_data(
#     612         X,
#     613         accept_sparse="csr",
#     614         dtype=np.float64,
#     615         order="C",
#     616         accept_large_sparse=False,
#     617         reset=False,
#     618     )
#     620 if self._sparse and not sp.isspmatrix(X):
#     621     X = sp.csr_matrix(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:625, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
# --> 625     self._check_n_features(X, reset=reset)
#     627 return out
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:414, in BaseEstimator._check_n_features(self, X, reset)
#     411     return
#     413 if n_features != self.n_features_in_:
# --> 414     raise ValueError(
#     415         f"X has {n_features} features, but {self.__class__.__name__} "
#     416         f"is expecting {self.n_features_in_} features as input."
#     417     )
#
# ValueError: X has 5 features, but SVR is expecting 7 features as input.

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test, y_pred)
r_score

# %%
# import pickle 
# filename = "finalized_model_SVM.sav"
# pickle.dump(regressor,open(filename,'wb'))
